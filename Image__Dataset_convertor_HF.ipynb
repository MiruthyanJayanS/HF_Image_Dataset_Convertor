# %%
# !pip install -q datasets transformers #supporting libraries
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.2 MB/s eta 0:00:00

# %%
#hugging face login
#enter the seceret token for hugging face
from huggingface_hub import notebook_login

notebook_login()

# %%
#Mount your google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls -al "/content/drive/MyDrive/Project" #list the files in the project folder

# %%
# !unzip "/content/drive/MyDrive/Project/Classification.zip" -d /tmp/Classify #unzip the dataset

# %%
#load the dataset
from datasets import load_dataset
ds = load_dataset("imagefolder", data_dir="/tmp/Classify")
ds = ds['train']

# %%
data = ds.train_test_split(test_size=0.15)#split the dataset into train and test

# %%
data#display the dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 114
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 21
#     })
# })

# %%
data.push_to_hub("username/desired_repo_name")#push the dataset to hugging face
